# %% [markdown]
# <a href="https://colab.research.google.com/github/bachi-mohamed-rafik/ML_intro/blob/main/1Housing_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Prediction House prices in Boston

# %%
# imports
import pandas as pd
import numpy as np
from sklearn.datasets import load_boston
from sklearn import datasets, linear_model, metrics 
from sklearn.model_selection import train_test_split

# %%
boston = load_boston()
print(boston.data.shape)
# Out:
# (506, 13)

# %%
#
x=pd.DataFrame(boston.data,columns=boston.feature_names)
y=pd.DataFrame(boston.target)
print(x)
print(y)
x.describe()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0    0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1    0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2    0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3    0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4    0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
# ..       ...   ...    ...   ...    ...  ...  ...    ...      ...     ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  391.99   9.67
# 502  0.04527   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   9.08
# 503  0.06076   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   5.64
# 504  0.10959   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  393.45   6.48
# 505  0.04741   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   7.88
#
# ...

# %%
#Making a linear regression
from sklearn.model_selection import train_test_split
reg = linear_model.LinearRegression()

x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.4,random_state=1)
print(x_train)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...   RAD    TAX  PTRATIO       B  LSTAT
# 452  5.09017   0.0  18.10   0.0  0.713  ...  24.0  666.0     20.2  385.09  17.27
# 346  0.06162   0.0   4.39   0.0  0.442  ...   3.0  352.0     18.8  364.61  12.67
# 295  0.12932   0.0  13.92   0.0  0.437  ...   4.0  289.0     16.0  396.90   6.27
# 88   0.05660   0.0   3.41   0.0  0.489  ...   2.0  270.0     17.8  396.90   5.50
# 322  0.35114   0.0   7.38   0.0  0.493  ...   5.0  287.0     19.6  396.90   7.70
# ..       ...   ...    ...   ...    ...  ...   ...    ...      ...     ...    ...
# 255  0.03548  80.0   3.64   0.0  0.392  ...   1.0  315.0     16.4  395.18   9.25
# 72   0.09164   0.0  10.81   0.0  0.413  ...   4.0  305.0     19.2  390.91   5.52
# 396  5.87205   0.0  18.10   0.0  0.693  ...  24.0  666.0     20.2  396.90  19.37
# 235  0.33045   0.0   6.20   0.0  0.507  ...   8.0  307.0     17.4  376.75  10.88
# 37   0.08014   0.0   5.96   0.0  0.499  ...   5.0  279.0     19.2  396.90   8.77
#
# ...

# %%
#training the model using training set 
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Getting the regression coefficient
reg.coef_
# Out:
# array([[-8.95714048e-02,  6.73132853e-02,  5.04649248e-02,
#          2.18579583e+00, -1.72053975e+01,  3.63606995e+00,
#          2.05579939e-03, -1.36602886e+00,  2.89576718e-01,
#         -1.22700072e-02, -8.34881849e-01,  9.40360790e-03,
#         -5.04008320e-01]])

# %%
#predict the house price
reg.predict(x_test)
# Out:
# array([[32.5767836 ],
#        [28.31584043],
#        [18.02490895],
#        [21.22723902],
#        [18.30706301],
#        [20.41855673],
#        [33.00388637],
#        [18.23492365],
#        [24.15996405],
#        [26.44388935],
#        [26.89587445],
#        [29.11404673],
#        [20.47403529],
#        [26.72290735],
#        [23.00917779],
#        [20.06036007],
#        [17.93614868],
#        [38.60918158],
#        [30.21848598],
#        [ 8.72510853],
#        [20.4218793 ],
#        [15.62926355],
#        [25.14572116],
#        [24.8208665 ],
#        [31.33254683],
#        [10.32111619],
#        [13.97300109],
#        [16.59941009],
#        [36.11111224],
#        [14.50980925],
#        [21.75924461],
#        [14.18085506],
#        [43.80568262],
#        [18.29067878],
#        [21.0769219 ],
#        [20.36535011],
#        [17.77192542],
#        [27.41157074],
#        [ 8.78516292],
#        [19.77211274],
#        [23.57601701],
# ...

# %%
#MSE
MSE = np.square(np.subtract(y_test,reg.predict(x_test))).mean()
print(MSE)
# Out:
# 0    25.205775
# dtype: float64
